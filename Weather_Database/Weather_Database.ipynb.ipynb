# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)


# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 718

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]        
       # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        city_weather_description = city_weather["weather"][0]["description"]
        
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})
                          #"Date": city_date})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | provideniya
# Processing Record 2 of Set 1 | new norfolk
# Processing Record 3 of Set 1 | weligama
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | castro
# Processing Record 6 of Set 1 | khorramabad
# Processing Record 7 of Set 1 | hithadhoo
# Processing Record 8 of Set 1 | westport
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | hasaki
# Processing Record 11 of Set 1 | hermanus
# Processing Record 12 of Set 1 | lebu
# Processing Record 13 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 1 | kaitangata
# Processing Record 16 of Set 1 | macas
# Processing Record 17 of Set 1 | belmonte
# Processing Record 18 of Set 1 | avarua
# Processing Record 19 of Set 1 | ondjiva
# Processing Record 20 of Set 1 | butaritari
# Processing Record 21 of Set 1 | tuatapere
# Processing Record 22 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 1 | khatanga
# Processing Record 24 of Set 1 | the valley
# Processing Record 25 of Set 1 | tocache
# Processing Record 26 of Set 1 | esperance
# Processing Record 27 of Set 1 | yellowknife
# Processing Record 28 of Set 1 | ushuaia
# Processing Record 29 of Set 1 | flinders
# Processing Record 30 of Set 1 | jamestown
# Processing Record 31 of Set 1 | nicolet
# Processing Record 32 of Set 1 | puerto ayora
# Processing Record 33 of Set 1 | hohhot
# Processing Record 34 of Set 1 | vaini
# Processing Record 35 of Set 1 | chambersburg
# Processing Record 36 of Set 1 | mayo
# Processing Record 37 of Set 1 | torbay
# Processing Record 38 of Set 1 | nanortalik
# Processing Record 39 of Set 1 | onega
# Processing Record 40 of Set 1 | prince rupert
# Processing Record 41 of Set 1 | mataura
# Processing Record 42 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 1 | morant bay
# Processing Record 44 of Set 1 | dikson
# Processing Record 45 of Set 1 | mahebourg
# Processing Record 46 of Set 1 | amapa
# Processing Record 47 of Set 1 | pangnirtung
# Processing Record 48 of Set 1 | saint-philippe
# Processing Record 49 of Set 1 | srednekolymsk
# Processing Record 50 of Set 1 | flin flon
# Processing Record 1 of Set 2 | west helena
# Processing Record 2 of Set 2 | sitka
# Processing Record 3 of Set 2 | punta arenas
# Processing Record 4 of Set 2 | arraial do cabo
# Processing Record 5 of Set 2 | tres arroyos
# Processing Record 6 of Set 2 | bethel
# Processing Record 7 of Set 2 | banjar
# Processing Record 8 of Set 2 | bredasdorp
# Processing Record 9 of Set 2 | hilo
# Processing Record 10 of Set 2 | fortuna
# Processing Record 11 of Set 2 | rajauri
# Processing Record 12 of Set 2 | bluff
# Processing Record 13 of Set 2 | kerema
# Processing Record 14 of Set 2 | shalakusha
# Processing Record 15 of Set 2 | barrow
# Processing Record 16 of Set 2 | garm
# City not found. Skipping...
# Processing Record 17 of Set 2 | tuktoyaktuk
# Processing Record 18 of Set 2 | georgetown
# Processing Record 19 of Set 2 | thompson
# Processing Record 20 of Set 2 | dakar
# Processing Record 21 of Set 2 | mayumba
# Processing Record 22 of Set 2 | moose factory
# Processing Record 23 of Set 2 | sambava
# Processing Record 24 of Set 2 | amazar
# Processing Record 25 of Set 2 | batagay-alyta
# Processing Record 26 of Set 2 | katsuura
# Processing Record 27 of Set 2 | albany
# Processing Record 28 of Set 2 | tiksi
# Processing Record 29 of Set 2 | warrington
# Processing Record 30 of Set 2 | port blair
# Processing Record 31 of Set 2 | abu samrah
# Processing Record 32 of Set 2 | saint george
# Processing Record 33 of Set 2 | hamilton
# Processing Record 34 of Set 2 | codrington
# Processing Record 35 of Set 2 | hobart
# Processing Record 36 of Set 2 | grindavik
# Processing Record 37 of Set 2 | rawson
# Processing Record 38 of Set 2 | ust-kishert
# Processing Record 39 of Set 2 | celestun
# Processing Record 40 of Set 2 | hualmay
# Processing Record 41 of Set 2 | ribeira grande
# Processing Record 42 of Set 2 | norman wells
# Processing Record 43 of Set 2 | kapaa
# Processing Record 44 of Set 2 | bubaque
# Processing Record 45 of Set 2 | cape town
# Processing Record 46 of Set 2 | denpasar
# Processing Record 47 of Set 2 | airai
# Processing Record 48 of Set 2 | ocean city
# Processing Record 49 of Set 2 | iberia
# Processing Record 50 of Set 2 | huarmey
# Processing Record 1 of Set 3 | kununurra
# Processing Record 2 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 3 of Set 3 | saldanha
# Processing Record 4 of Set 3 | ewa beach
# Processing Record 5 of Set 3 | tynda
# Processing Record 6 of Set 3 | steamboat springs
# Processing Record 7 of Set 3 | severo-kurilsk
# Processing Record 8 of Set 3 | kodiak
# Processing Record 9 of Set 3 | sao jose da coroa grande
# Processing Record 10 of Set 3 | najran
# Processing Record 11 of Set 3 | camacha
# Processing Record 12 of Set 3 | mount gambier
# Processing Record 13 of Set 3 | bousso
# Processing Record 14 of Set 3 | chunhuhub
# Processing Record 15 of Set 3 | noumea
# Processing Record 16 of Set 3 | cap-aux-meules
# Processing Record 17 of Set 3 | biograd na moru
# Processing Record 18 of Set 3 | qaanaaq
# Processing Record 19 of Set 3 | east london
# Processing Record 20 of Set 3 | tura
# Processing Record 21 of Set 3 | pisco
# Processing Record 22 of Set 3 | tasiilaq
# Processing Record 23 of Set 3 | goderich
# Processing Record 24 of Set 3 | mounana
# Processing Record 25 of Set 3 | ishinomaki
# Processing Record 26 of Set 3 | savelugu
# Processing Record 27 of Set 3 | dingle
# Processing Record 28 of Set 3 | booue
# Processing Record 29 of Set 3 | altoona
# Processing Record 30 of Set 3 | bani
# Processing Record 31 of Set 3 | lauria
# Processing Record 32 of Set 3 | skiros
# City not found. Skipping...
# Processing Record 33 of Set 3 | stepnyak
# Processing Record 34 of Set 3 | faanui
# Processing Record 35 of Set 3 | lagoa
# Processing Record 36 of Set 3 | santa rosa
# Processing Record 37 of Set 3 | upernavik
# Processing Record 38 of Set 3 | clyde river
# Processing Record 39 of Set 3 | yar-sale
# Processing Record 40 of Set 3 | hami
# Processing Record 41 of Set 3 | boa vista
# Processing Record 42 of Set 3 | udachnyy
# Processing Record 43 of Set 3 | necochea
# Processing Record 44 of Set 3 | bengkulu
# Processing Record 45 of Set 3 | vao
# Processing Record 46 of Set 3 | naze
# Processing Record 47 of Set 3 | asau
# Processing Record 48 of Set 3 | nuuk
# Processing Record 49 of Set 3 | ariquemes
# Processing Record 50 of Set 3 | port elizabeth
# Processing Record 1 of Set 4 | batemans bay
# Processing Record 2 of Set 4 | adrar
# Processing Record 3 of Set 4 | willowmore
# Processing Record 4 of Set 4 | atuona
# Processing Record 5 of Set 4 | peno
# Processing Record 6 of Set 4 | san patricio
# Processing Record 7 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 4 | ilulissat
# Processing Record 9 of Set 4 | ha giang
# Processing Record 10 of Set 4 | conde
# Processing Record 11 of Set 4 | mana
# Processing Record 12 of Set 4 | chabahar
# Processing Record 13 of Set 4 | hurghada
# Processing Record 14 of Set 4 | kimbe
# Processing Record 15 of Set 4 | patur
# Processing Record 16 of Set 4 | camana
# Processing Record 17 of Set 4 | ciudad bolivar
# Processing Record 18 of Set 4 | lorengau
# Processing Record 19 of Set 4 | taltal
# Processing Record 20 of Set 4 | cayenne
# Processing Record 21 of Set 4 | manta
# Processing Record 22 of Set 4 | moron
# Processing Record 23 of Set 4 | biak
# Processing Record 24 of Set 4 | touros
# Processing Record 25 of Set 4 | chokurdakh
# Processing Record 26 of Set 4 | san rafael
# Processing Record 27 of Set 4 | akureyri
# Processing Record 28 of Set 4 | meulaboh
# Processing Record 29 of Set 4 | tiptur
# Processing Record 30 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 4 | kahului
# Processing Record 32 of Set 4 | mar del plata
# Processing Record 33 of Set 4 | dwarka
# Processing Record 34 of Set 4 | midland
# Processing Record 35 of Set 4 | guadalupe victoria
# Processing Record 36 of Set 4 | ixtapa
# Processing Record 37 of Set 4 | weymouth
# Processing Record 38 of Set 4 | olinda
# Processing Record 39 of Set 4 | qunduz
# Processing Record 40 of Set 4 | luau
# Processing Record 41 of Set 4 | juneau
# Processing Record 42 of Set 4 | beringovskiy
# Processing Record 43 of Set 4 | tadine
# Processing Record 44 of Set 4 | kizukuri
# Processing Record 45 of Set 4 | ialibu
# Processing Record 46 of Set 4 | pilar
# Processing Record 47 of Set 4 | kavaratti
# Processing Record 48 of Set 4 | banda aceh
# Processing Record 49 of Set 4 | victoria
# Processing Record 50 of Set 4 | buala
# Processing Record 1 of Set 5 | kazerun
# Processing Record 2 of Set 5 | fairbanks
# Processing Record 3 of Set 5 | araouane
# Processing Record 4 of Set 5 | roald
# Processing Record 5 of Set 5 | talnakh
# Processing Record 6 of Set 5 | namibe
# Processing Record 7 of Set 5 | raga
# Processing Record 8 of Set 5 | port hedland
# Processing Record 9 of Set 5 | berlevag
# Processing Record 10 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 5 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 12 of Set 5 | cidreira
# Processing Record 13 of Set 5 | axim
# Processing Record 14 of Set 5 | helong
# Processing Record 15 of Set 5 | barcelos
# Processing Record 16 of Set 5 | narsaq
# Processing Record 17 of Set 5 | urumqi
# Processing Record 18 of Set 5 | cairns
# Processing Record 19 of Set 5 | alekseyevka
# Processing Record 20 of Set 5 | san cristobal
# Processing Record 21 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 5 | gigmoto
# Processing Record 23 of Set 5 | turukhansk
# Processing Record 24 of Set 5 | broome
# Processing Record 25 of Set 5 | aracruz
# Processing Record 26 of Set 5 | maralal
# Processing Record 27 of Set 5 | souillac
# Processing Record 28 of Set 5 | perth
# Processing Record 29 of Set 5 | saskylakh
# Processing Record 30 of Set 5 | doume
# Processing Record 31 of Set 5 | kavieng
# Processing Record 32 of Set 5 | santa fe
# Processing Record 33 of Set 5 | bikaner
# Processing Record 34 of Set 5 | bowen
# Processing Record 35 of Set 5 | okhotsk
# Processing Record 36 of Set 5 | alexandria
# Processing Record 37 of Set 5 | pamanukan
# Processing Record 38 of Set 5 | kisujszallas
# Processing Record 39 of Set 5 | kanniyakumari
# Processing Record 40 of Set 5 | shar
# Processing Record 41 of Set 5 | lovozero
# Processing Record 42 of Set 5 | vila franca do campo
# Processing Record 43 of Set 5 | maragogi
# Processing Record 44 of Set 5 | mazatan
# Processing Record 45 of Set 5 | chabua
# Processing Record 46 of Set 5 | husavik
# Processing Record 47 of Set 5 | sao filipe
# Processing Record 48 of Set 5 | castelo do piaui
# Processing Record 49 of Set 5 | canchungo
# Processing Record 50 of Set 5 | vardo
# Processing Record 1 of Set 6 | deputatskiy
# Processing Record 2 of Set 6 | ponta do sol
# Processing Record 3 of Set 6 | arauca
# Processing Record 4 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 5 of Set 6 | alofi
# Processing Record 6 of Set 6 | maua
# Processing Record 7 of Set 6 | yaan
# Processing Record 8 of Set 6 | portland
# Processing Record 9 of Set 6 | robertson
# Processing Record 10 of Set 6 | jaisalmer
# Processing Record 11 of Set 6 | koppies
# Processing Record 12 of Set 6 | milkovo
# Processing Record 13 of Set 6 | acapulco
# Processing Record 14 of Set 6 | atuntaqui
# Processing Record 15 of Set 6 | kihei
# Processing Record 16 of Set 6 | anshun
# Processing Record 17 of Set 6 | vershino-darasunskiy
# Processing Record 18 of Set 6 | eyrarbakki
# Processing Record 19 of Set 6 | kabalo
# Processing Record 20 of Set 6 | nikolskoye
# Processing Record 21 of Set 6 | belyy yar
# Processing Record 22 of Set 6 | chicama
# Processing Record 23 of Set 6 | majene
# Processing Record 24 of Set 6 | egvekinot
# Processing Record 25 of Set 6 | richards bay
# Processing Record 26 of Set 6 | nemyriv
# Processing Record 27 of Set 6 | bay roberts
# Processing Record 28 of Set 6 | yei
# Processing Record 29 of Set 6 | tomatlan
# Processing Record 30 of Set 6 | fort nelson
# Processing Record 31 of Set 6 | longyearbyen
# Processing Record 32 of Set 6 | lavrentiya
# Processing Record 33 of Set 6 | atambua
# Processing Record 34 of Set 6 | tukrah
# Processing Record 35 of Set 6 | sicamous
# Processing Record 36 of Set 6 | labytnangi
# Processing Record 37 of Set 6 | oranjemund
# Processing Record 38 of Set 6 | hay river
# Processing Record 39 of Set 6 | avera
# Processing Record 40 of Set 6 | morehead
# Processing Record 41 of Set 6 | kloulklubed
# Processing Record 42 of Set 6 | coracora
# Processing Record 43 of Set 6 | grand gaube
# Processing Record 44 of Set 6 | cherskiy
# Processing Record 45 of Set 6 | maamba
# Processing Record 46 of Set 6 | nizwa
# Processing Record 47 of Set 6 | neiafu
# Processing Record 48 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 6 | fastiv
# Processing Record 50 of Set 6 | danville
# Processing Record 1 of Set 7 | beihai
# Processing Record 2 of Set 7 | durgapur
# Processing Record 3 of Set 7 | tiznit
# Processing Record 4 of Set 7 | san policarpo
# Processing Record 5 of Set 7 | chuy
# Processing Record 6 of Set 7 | rocha
# Processing Record 7 of Set 7 | bitung
# Processing Record 8 of Set 7 | saint-pierre
# Processing Record 9 of Set 7 | beloha
# Processing Record 10 of Set 7 | otane
# Processing Record 11 of Set 7 | tautira
# Processing Record 12 of Set 7 | guira de melena
# Processing Record 13 of Set 7 | eureka
# Processing Record 14 of Set 7 | constitucion
# Processing Record 15 of Set 7 | batticaloa
# Processing Record 16 of Set 7 | murgab
# Processing Record 17 of Set 7 | sur
# Processing Record 18 of Set 7 | waingapu
# Processing Record 19 of Set 7 | stornoway
# Processing Record 20 of Set 7 | boisoara
# Processing Record 21 of Set 7 | khandyga
# Processing Record 22 of Set 7 | klaksvik
# Processing Record 23 of Set 7 | matay
# Processing Record 24 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 25 of Set 7 | chaman
# Processing Record 26 of Set 7 | gamba
# Processing Record 27 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 7 | carnarvon
# Processing Record 29 of Set 7 | port alfred
# Processing Record 30 of Set 7 | maneadero
# Processing Record 31 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 32 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 7 | taloqan
# Processing Record 34 of Set 7 | yatou
# Processing Record 35 of Set 7 | lamar
# Processing Record 36 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 37 of Set 7 | sorland
# Processing Record 38 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 7 | nelson bay
# Processing Record 40 of Set 7 | shelburne
# Processing Record 41 of Set 7 | mingguang
# Processing Record 42 of Set 7 | kruisfontein
# Processing Record 43 of Set 7 | hirara
# Processing Record 44 of Set 7 | markova
# Processing Record 45 of Set 7 | iqaluit
# Processing Record 46 of Set 7 | la ronge
# Processing Record 47 of Set 7 | havre-saint-pierre
# Processing Record 48 of Set 7 | sibu
# Processing Record 49 of Set 7 | mlonggo
# Processing Record 50 of Set 7 | bassano
# Processing Record 1 of Set 8 | kiruna
# Processing Record 2 of Set 8 | morros
# Processing Record 3 of Set 8 | sobolevo
# Processing Record 4 of Set 8 | llanes
# Processing Record 5 of Set 8 | kaeo
# Processing Record 6 of Set 8 | marawi
# Processing Record 7 of Set 8 | labuhan
# Processing Record 8 of Set 8 | los llanos de aridane
# Processing Record 9 of Set 8 | kupang
# Processing Record 10 of Set 8 | lompoc
# Processing Record 11 of Set 8 | yulara
# Processing Record 12 of Set 8 | mattru
# Processing Record 13 of Set 8 | tezu
# Processing Record 14 of Set 8 | qui nhon
# Processing Record 15 of Set 8 | kroderen
# City not found. Skipping...
# Processing Record 16 of Set 8 | cap malheureux
# Processing Record 17 of Set 8 | mogadishu
# Processing Record 18 of Set 8 | maun
# Processing Record 19 of Set 8 | puerto escondido
# Processing Record 20 of Set 8 | broken hill
# Processing Record 21 of Set 8 | batsfjord
# Processing Record 22 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 8 | olafsvik
# Processing Record 24 of Set 8 | newton
# Processing Record 25 of Set 8 | lundazi
# Processing Record 26 of Set 8 | coquimbo
# Processing Record 27 of Set 8 | leningradskiy
# Processing Record 28 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 29 of Set 8 | aksu
# Processing Record 30 of Set 8 | noyabrsk
# Processing Record 31 of Set 8 | kabale
# Processing Record 32 of Set 8 | san javier
# Processing Record 33 of Set 8 | alotau
# City not found. Skipping...
# Processing Record 34 of Set 8 | kungurtug
# Processing Record 35 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 8 | killybegs
# Processing Record 37 of Set 8 | goundam
# Processing Record 38 of Set 8 | pevek
# Processing Record 39 of Set 8 | camacupa
# Processing Record 40 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 41 of Set 8 | namatanai
# Processing Record 42 of Set 8 | aklavik
# Processing Record 43 of Set 8 | kolno
# Processing Record 44 of Set 8 | pavilosta
# Processing Record 45 of Set 8 | kathu
# Processing Record 46 of Set 8 | pangai
# Processing Record 47 of Set 8 | monterey
# Processing Record 48 of Set 8 | pustoshka
# Processing Record 49 of Set 8 | padre paraiso
# Processing Record 50 of Set 8 | cockburn town
# Processing Record 1 of Set 9 | beruwala
# Processing Record 2 of Set 9 | port augusta
# Processing Record 3 of Set 9 | slave lake
# Processing Record 4 of Set 9 | inderborskiy
# City not found. Skipping...
# Processing Record 5 of Set 9 | ancud
# Processing Record 6 of Set 9 | ust-maya
# Processing Record 7 of Set 9 | hokitika
# Processing Record 8 of Set 9 | wageningen
# Processing Record 9 of Set 9 | honningsvag
# Processing Record 10 of Set 9 | zacualpan
# Processing Record 11 of Set 9 | general cepeda
# Processing Record 12 of Set 9 | port-cartier
# Processing Record 13 of Set 9 | maiduguri
# Processing Record 14 of Set 9 | pantai remis
# Processing Record 15 of Set 9 | port lincoln
# Processing Record 16 of Set 9 | jinchang
# Processing Record 17 of Set 9 | boyolangu
# Processing Record 18 of Set 9 | burica
# City not found. Skipping...
# Processing Record 19 of Set 9 | homer
# Processing Record 20 of Set 9 | kodinsk
# Processing Record 21 of Set 9 | presidencia roque saenz pena
# Processing Record 22 of Set 9 | pahrump
# Processing Record 23 of Set 9 | bundaberg
# Processing Record 24 of Set 9 | gamprin
# Processing Record 25 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 9 | ginda
# Processing Record 27 of Set 9 | nome
# Processing Record 28 of Set 9 | kalmunai
# Processing Record 29 of Set 9 | tuscaloosa
# Processing Record 30 of Set 9 | bentiu
# Processing Record 31 of Set 9 | burnie
# Processing Record 32 of Set 9 | kendari
# Processing Record 33 of Set 9 | eyemouth
# Processing Record 34 of Set 9 | sonoita
# Processing Record 35 of Set 9 | laviana
# Processing Record 36 of Set 9 | aswan
# Processing Record 37 of Set 9 | evensk
# Processing Record 38 of Set 9 | auxerre
# Processing Record 39 of Set 9 | neijiang
# Processing Record 40 of Set 9 | puerto el triunfo
# Processing Record 41 of Set 9 | bira
# Processing Record 42 of Set 9 | acurenam
# Processing Record 43 of Set 9 | chapais
# Processing Record 44 of Set 9 | balkanabat
# Processing Record 45 of Set 9 | half moon bay
# Processing Record 46 of Set 9 | dong hoi
# Processing Record 47 of Set 9 | bokspits
# City not found. Skipping...
# Processing Record 48 of Set 9 | buta
# Processing Record 49 of Set 9 | puerto ayacucho
# Processing Record 50 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 1 of Set 10 | pilot butte
# Processing Record 2 of Set 10 | parlakimidi
# Processing Record 3 of Set 10 | poum
# Processing Record 4 of Set 10 | arlit
# Processing Record 5 of Set 10 | temaraia
# City not found. Skipping...
# Processing Record 6 of Set 10 | tamandare
# Processing Record 7 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 8 of Set 10 | kyaikkami
# Processing Record 9 of Set 10 | barauna
# Processing Record 10 of Set 10 | maceio
# Processing Record 11 of Set 10 | san joaquin
# Processing Record 12 of Set 10 | ostrovnoy
# Processing Record 13 of Set 10 | newport beach
# Processing Record 14 of Set 10 | newcastle
# Processing Record 15 of Set 10 | winslow
# Processing Record 16 of Set 10 | ahipara
# Processing Record 17 of Set 10 | cabo san lucas
# Processing Record 18 of Set 10 | sinnamary
# Processing Record 19 of Set 10 | svetlaya
# Processing Record 20 of Set 10 | linares
# Processing Record 21 of Set 10 | padang
# Processing Record 22 of Set 10 | bobonong
# City not found. Skipping...
# Processing Record 23 of Set 10 | north platte
# Processing Record 24 of Set 10 | shimoda
# Processing Record 25 of Set 10 | chimbote
# Processing Record 26 of Set 10 | klyuchi
# Processing Record 27 of Set 10 | azare
# Processing Record 28 of Set 10 | denizli
# Processing Record 29 of Set 10 | deloraine
# Processing Record 30 of Set 10 | ekimchan
# Processing Record 31 of Set 10 | san andres
# Processing Record 32 of Set 10 | zyryanskoye
# Processing Record 33 of Set 10 | baykit
# Processing Record 34 of Set 10 | tlaxiaco
# City not found. Skipping...
# Processing Record 35 of Set 10 | walvis bay
# Processing Record 36 of Set 10 | saint-georges
# Processing Record 37 of Set 10 | puerto del rosario
# Processing Record 38 of Set 10 | kisangani
# Processing Record 39 of Set 10 | katsiveli
# City not found. Skipping...
# Processing Record 40 of Set 10 | samarai
# Processing Record 41 of Set 10 | mokhsogollokh
# Processing Record 42 of Set 10 | pontes e lacerda
# Processing Record 43 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 10 | saint anthony
# Processing Record 45 of Set 10 | mehamn
# Processing Record 46 of Set 10 | taunggyi
# Processing Record 47 of Set 10 | kontagora
# Processing Record 48 of Set 10 | karratha
# Processing Record 49 of Set 10 | gravdal
# Processing Record 50 of Set 10 | geraldton
# Processing Record 1 of Set 11 | marzuq
# Processing Record 2 of Set 11 | el playon
# Processing Record 3 of Set 11 | ust-kuyga
# Processing Record 4 of Set 11 | hun
# Processing Record 5 of Set 11 | medicine hat
# Processing Record 6 of Set 11 | galveston
# Processing Record 7 of Set 11 | mvangue
# Processing Record 8 of Set 11 | salalah
# Processing Record 9 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 10 of Set 11 | tabou
# Processing Record 11 of Set 11 | boqueirao
# Processing Record 12 of Set 11 | auki
# Processing Record 13 of Set 11 | paamiut
# Processing Record 14 of Set 11 | belaya gora
# Processing Record 15 of Set 11 | jatai
# Processing Record 16 of Set 11 | calvinia
# Processing Record 17 of Set 11 | hofn
# Processing Record 18 of Set 11 | susuman
# Processing Record 19 of Set 11 | rockland
# Processing Record 20 of Set 11 | mocuba
# Processing Record 21 of Set 11 | vitina
# Processing Record 22 of Set 11 | ambulu
# Processing Record 23 of Set 11 | bouna
# Processing Record 24 of Set 11 | alice springs
# Processing Record 25 of Set 11 | meadow lake
# Processing Record 26 of Set 11 | mazatlan
# Processing Record 27 of Set 11 | laguna
# Processing Record 28 of Set 11 | doha
# Processing Record 29 of Set 11 | tilichiki
# Processing Record 30 of Set 11 | mount isa
# Processing Record 31 of Set 11 | muros
# Processing Record 32 of Set 11 | umm lajj
# Processing Record 33 of Set 11 | songjianghe
# Processing Record 34 of Set 11 | yirol
# City not found. Skipping...
# Processing Record 35 of Set 11 | vila velha
# Processing Record 36 of Set 11 | lima
# Processing Record 37 of Set 11 | opuwo
# Processing Record 38 of Set 11 | swellendam
# Processing Record 39 of Set 11 | zonguldak
# Processing Record 40 of Set 11 | hinganghat
# Processing Record 41 of Set 11 | suamico
# Processing Record 42 of Set 11 | xining
# Processing Record 43 of Set 11 | chernyshevskiy
# Processing Record 44 of Set 11 | fare
# Processing Record 45 of Set 11 | praya
# Processing Record 46 of Set 11 | chara
# Processing Record 47 of Set 11 | san felipe
# Processing Record 48 of Set 11 | birjand
# Processing Record 49 of Set 11 | kieta
# Processing Record 50 of Set 11 | taoudenni
# Processing Record 1 of Set 12 | erdemli
# Processing Record 2 of Set 12 | rawlins
# Processing Record 3 of Set 12 | aykhal
# Processing Record 4 of Set 12 | amahai
# Processing Record 5 of Set 12 | consuegra
# Processing Record 6 of Set 12 | bandarbeyla
# Processing Record 7 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 8 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 9 of Set 12 | oksfjord
# Processing Record 10 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 11 of Set 12 | vanavara
# Processing Record 12 of Set 12 | fredericksburg
# Processing Record 13 of Set 12 | emerald
# Processing Record 14 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 15 of Set 12 | zhanaozen
# Processing Record 16 of Set 12 | tari
# Processing Record 17 of Set 12 | narwar
# Processing Record 18 of Set 12 | zhaozhou
# Processing Record 19 of Set 12 | henties bay
# Processing Record 20 of Set 12 | bonavista
# Processing Record 21 of Set 12 | san juan
# Processing Record 22 of Set 12 | porto novo
# Processing Record 23 of Set 12 | takoradi
# Processing Record 24 of Set 12 | christchurch
# Processing Record 25 of Set 12 | anadyr
# Processing Record 26 of Set 12 | inhambane
# Processing Record 27 of Set 12 | nago
# Processing Record 28 of Set 12 | kemin
# Processing Record 29 of Set 12 | krasnoborsk
# Processing Record 30 of Set 12 | nipawin
# Processing Record 31 of Set 12 | fereydun kenar
# Processing Record 32 of Set 12 | moussoro
# Processing Record 33 of Set 12 | kirensk
# Processing Record 34 of Set 12 | dalvik
# Processing Record 35 of Set 12 | tecoanapa
# Processing Record 36 of Set 12 | vanimo
# Processing Record 37 of Set 12 | treinta y tres
# Processing Record 38 of Set 12 | vestmannaeyjar
# Processing Record 39 of Set 12 | bolobo
# Processing Record 40 of Set 12 | te anau
# Processing Record 41 of Set 12 | polyanka
# Processing Record 42 of Set 12 | pincher creek
# Processing Record 43 of Set 12 | leo
# Processing Record 44 of Set 12 | beisfjord
# Processing Record 45 of Set 12 | irece
# Processing Record 46 of Set 12 | qandahar
# City not found. Skipping...
# Processing Record 47 of Set 12 | lampa
# Processing Record 48 of Set 12 | phalombe
# Processing Record 49 of Set 12 | san quintin
# Processing Record 50 of Set 12 | dargaville
# Processing Record 1 of Set 13 | chechat
# Processing Record 2 of Set 13 | grand-santi
# Processing Record 3 of Set 13 | matucana
# Processing Record 4 of Set 13 | mangan
# Processing Record 5 of Set 13 | havoysund
# Processing Record 6 of Set 13 | ornskoldsvik
# Processing Record 7 of Set 13 | tarakan
# Processing Record 8 of Set 13 | saquarema
# Processing Record 9 of Set 13 | katiola
# Processing Record 10 of Set 13 | saint-francois
# Processing Record 11 of Set 13 | pascagoula
# Processing Record 12 of Set 13 | rochegda
# Processing Record 13 of Set 13 | bossier city
# Processing Record 14 of Set 13 | bafoulabe
# Processing Record 15 of Set 13 | eyl
# Processing Record 16 of Set 13 | margate
# Processing Record 17 of Set 13 | dumas
# Processing Record 18 of Set 13 | palm coast
# Processing Record 19 of Set 13 | cagsiay
# Processing Record 20 of Set 13 | salinas
# Processing Record 21 of Set 13 | madang
# Processing Record 22 of Set 13 | vavatenina
# Processing Record 23 of Set 13 | jiuquan
# Processing Record 24 of Set 13 | wagrowiec
# Processing Record 25 of Set 13 | ojinaga
# Processing Record 26 of Set 13 | tortoli
# Processing Record 27 of Set 13 | pena
# Processing Record 28 of Set 13 | palmerston
# Processing Record 29 of Set 13 | riyadh
# Processing Record 30 of Set 13 | iwanai
# Processing Record 31 of Set 13 | kaduna
# Processing Record 32 of Set 13 | price
# Processing Record 33 of Set 13 | lopsmarka
# Processing Record 34 of Set 13 | melenci
# Processing Record 35 of Set 13 | whitehorse
# Processing Record 36 of Set 13 | porto velho
# Processing Record 37 of Set 13 | luanda
# Processing Record 38 of Set 13 | tyup
# Processing Record 39 of Set 13 | chodavaram
# Processing Record 40 of Set 13 | port-gentil
# Processing Record 41 of Set 13 | sovetskiy
# Processing Record 42 of Set 13 | taksimo
# Processing Record 43 of Set 13 | el alto
# Processing Record 44 of Set 13 | bathsheba
# Processing Record 45 of Set 13 | apastovo
# Processing Record 46 of Set 13 | ossora
# Processing Record 47 of Set 13 | mersing
# Processing Record 48 of Set 13 | machico
# Processing Record 49 of Set 13 | tyulyachi
# Processing Record 50 of Set 13 | gunjur
# Processing Record 1 of Set 14 | lixourion
# Processing Record 2 of Set 14 | flagstaff
# Processing Record 3 of Set 14 | tacuati
# Processing Record 4 of Set 14 | nurota
# Processing Record 5 of Set 14 | teahupoo
# Processing Record 6 of Set 14 | glace bay
# Processing Record 7 of Set 14 | worthington
# Processing Record 8 of Set 14 | spring valley
# Processing Record 9 of Set 14 | teodoro sampaio
# Processing Record 10 of Set 14 | andenes
# Processing Record 11 of Set 14 | nantucket
# Processing Record 12 of Set 14 | bambous virieux
# Processing Record 13 of Set 14 | coihaique
# Processing Record 14 of Set 14 | kargopol
# Processing Record 15 of Set 14 | sechura
# Processing Record 16 of Set 14 | batuan
# Processing Record 17 of Set 14 | douentza
# Processing Record 18 of Set 14 | tazovskiy
# Processing Record 19 of Set 14 | ponnani
# Processing Record 20 of Set 14 | tambura
# Processing Record 21 of Set 14 | lasa
# Processing Record 22 of Set 14 | mutsamudu
# City not found. Skipping...
# Processing Record 23 of Set 14 | dzerzhinsk
# Processing Record 24 of Set 14 | bimbo
# Processing Record 25 of Set 14 | garut
# Processing Record 26 of Set 14 | orapa
# Processing Record 27 of Set 14 | sinkat
# City not found. Skipping...
# Processing Record 28 of Set 14 | lhokseumawe
# Processing Record 29 of Set 14 | santiago
# Processing Record 30 of Set 14 | ustka
# Processing Record 31 of Set 14 | nizhniy kuranakh
# Processing Record 32 of Set 14 | bonito
# Processing Record 33 of Set 14 | baruun-urt
# Processing Record 34 of Set 14 | kaspiysk
# Processing Record 35 of Set 14 | kainantu
# Processing Record 36 of Set 14 | bambanglipuro
# Processing Record 37 of Set 14 | mangai
# Processing Record 38 of Set 14 | prainha
# Processing Record 39 of Set 14 | madras
# Processing Record 40 of Set 14 | neya
# Processing Record 41 of Set 14 | lujiang
# Processing Record 42 of Set 14 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 43 of Set 14 | koshurnikovo
# Processing Record 44 of Set 14 | kidal
# Processing Record 45 of Set 14 | mahadday weyne
# City not found. Skipping...
# Processing Record 46 of Set 14 | galeana
# Processing Record 47 of Set 14 | waw
# Processing Record 48 of Set 14 | amga
# Processing Record 49 of Set 14 | enshi
# Processing Record 50 of Set 14 | aleksandrovka
# Processing Record 1 of Set 15 | tsienyane
# City not found. Skipping...
# Processing Record 2 of Set 15 | sarakhs
# Processing Record 3 of Set 15 | date
# Processing Record 4 of Set 15 | bom jesus
# Processing Record 5 of Set 15 | mitu
# Processing Record 6 of Set 15 | burgersdorp
# Processing Record 7 of Set 15 | praia da vitoria
# Processing Record 8 of Set 15 | nyrob
# Processing Record 9 of Set 15 | alihe
# Processing Record 10 of Set 15 | kresna
# Processing Record 11 of Set 15 | palauig
# Processing Record 12 of Set 15 | luganville
# Processing Record 13 of Set 15 | pafos
# Processing Record 14 of Set 15 | kiama
# Processing Record 15 of Set 15 | da nang
# Processing Record 16 of Set 15 | aquiraz
# Processing Record 17 of Set 15 | senneterre
# Processing Record 18 of Set 15 | cubuk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 670

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Provideniya  64.3833 -173.3000     -2.09        84          75        4.47
# 1  New Norfolk -42.7826  147.0587     60.93        60          18        1.01
# 2     Weligama   5.9667   80.4167     73.26        90          93        2.89
# 3      Rikitea -23.1203 -134.9692     79.20        70         100       16.84
# 4       Castro -24.7911  -50.0119     67.08        65          21        4.27
# 5  Khorramabad  33.4878   48.3558     37.02        87          75        4.61
# 6    Hithadhoo  -0.6000   73.0833     80.53        75          82        5.03
# 7     Westport  41.1415  -73.3579     44.64        55         100       21.85
# 8    Busselton -33.6500  115.3333     60.03        91          76        4.50
# 9       Hasaki  35.7333  140.8333     35.22        55         100        7.43
#
#   Country Current Description
# 0      RU       broken clouds
# 1      AU          few clouds
# 2      LK     overcast clouds
# 3      PF     overcast clouds
# 4      BR          few clouds
# 5      IR       broken clouds
# 6      MV       broken clouds
# 7      US     overcast clouds
# 8      AU       broken clouds
# 9      JP     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Provideniya      RU  64.3833 -173.3000     -2.09        84          75
# 1  New Norfolk      AU -42.7826  147.0587     60.93        60          18
# 2     Weligama      LK   5.9667   80.4167     73.26        90          93
# 3      Rikitea      PF -23.1203 -134.9692     79.20        70         100
# 4       Castro      BR -24.7911  -50.0119     67.08        65          21
# 5  Khorramabad      IR  33.4878   48.3558     37.02        87          75
# 6    Hithadhoo      MV  -0.6000   73.0833     80.53        75          82
# 7     Westport      US  41.1415  -73.3579     44.64        55         100
# 8    Busselton      AU -33.6500  115.3333     60.03        91          76
# 9       Hasaki      JP  35.7333  140.8333     35.22        55         100
#
#    Wind Speed Current Description
# 0        4.47       broken clouds
# 1        1.01          few clouds
# 2        2.89     overcast clouds
# 3       16.84     overcast clouds
# 4        4.27          few clouds
# 5        4.61       broken clouds
# 6        5.03       broken clouds
# 7       21.85     overcast clouds
# 8        4.50       broken clouds
# 9        7.43     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
